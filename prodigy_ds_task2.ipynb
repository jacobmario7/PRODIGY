# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/data science/gender_submission.csv")
data
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
data['Survived'].fillna(data['Survived'].median(), inplace=True)

# %%
survived=data['Survived'].value_counts()
survived
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x='Survived',data=data,palette="Set2",edgecolor='black',hue='Survived',legend='auto')
plt.title('Survival Count')
plt.show()

# %%
sns.barplot(x='PassengerId',y='Survived', data=data)
plt.figure(figsize=(8, 6))
plt.show()
